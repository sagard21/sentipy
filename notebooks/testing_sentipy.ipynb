# %%
import sys

# %%
sys.path.append('/Users/sagardawda/Desktop/Projects/sentipy/')

# %%
from sentipy.app.text_explainer import explain_text_features

# %%
# %matplotlib inline

# %%
outcome = explain_text_features('This is aweseome', num_features=3)
# Out:
# /anaconda3/envs/nlp/lib/python3.6/site-packages/lime/lime_text.py:114: FutureWarning: split() requires a non-empty pattern match.
#   self.as_list = [s for s in splitter.split(self.raw) if s]
